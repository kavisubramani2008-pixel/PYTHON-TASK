# %% [markdown]
# <a href="https://colab.research.google.com/github/kavisubramani2008-pixel/PYTHON-TASK/blob/main/task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#program 1
n = int(input())
print(n+2)

# %%
#problem 2
n = int(input())
print(n - 5)

# %%
#problem 3
n = int(input())
print(n * 3)

# %%
#problem 4
n = int(input())
print(n // 6)

# %%
#problem 5
n = int(input())
print(n % 8)

# %%
#problem 6
n = int(input())
print(n % 10)

# %%
#problem 7
n = int(input())
print(n // 10)

# %%
#problem 8
n = int(input())
print(n % 10)

# %%
#problem 9
n = int(input())
print(n // 100)

# %%
#problem 10
n = int(input())
print((n // 10) % 10)

# %%
#problem 11
n = int(input())
print(n // 10 + n % 10)

# %%
#problem 12
n = int(input())
print(n // 100 + (n // 10) % 10 + n % 10)

# %%
#problem 13
n = int(input())
print((n % 10) * 10 + n // 10)

# %%
#problem 14
n = int(input())
print((n % 10) * 100 + ((n // 10) % 10) * 10 + n // 100)

# %%
#problem 15
n = int(input())

a = n // 1000
b = (n // 100) % 10
c = (n // 10) % 10
d = n % 10

print(b * 1000 + a * 100 + c * 10 + d)

# %%
#problem 16
n = int(input())

a = n // 1000
b = (n // 100) % 10
c = (n // 10) % 10
d = n % 10

print(a * 1000 + b * 100 + d * 10 + c)

# %%
#problem 17
n = int(input())
print(n // 10 * 10)

# %%
#problem 18
n = int(input())
print(10 + n % 10)

# %%
#problem 19
n = int(input())
print(n // 10 * 10 + 2)

# %%
#problem 20
n = int(input())
print(n // 100 * 100 + n % 10)

# %%
#problem 21
n = int(input())
print(n - 5 * (n % 2))

# %%
#problem 22
n = int(input())
tens = (n // 10) % 10

print(n - 5 * (tens % 2))

# %%
#problem 23
n = int(input())

s = n // 10 + n % 10

print(n - 5 * (s % 2))

# %%
#problem 24
n = int(input())

first = n // 100
last = n % 10

print(n - 5 * (first == last))

# %%
#problem 25
n = int(input())

hundred = (n // 100) % 10
tens = (n // 10) % 10

print(n - 5 * (hundred == tens))

# %%
#problem 26
n = int(input())

s = n // 10 + n % 10

if s == 10:
    print("Success")
else:
    print("Failure")

# %%
#problem 27
n = int(input())

s = n // 100 + (n // 10) % 10 + n % 10

if s == 10:
    print("Success")
else:
    print("Failure")

# %%
#problem 28
n = int(input())

first = n // 100
last = n % 10

if first + last < 10:
    print("Success")
else:
    print("Failure")

# %%
#problem 29
n = int(input())

hundred = (n // 100) % 10
tens = (n // 10) % 10

if hundred + tens > 10:
    print("Success")
else:
    print("Failure")

# %%
#problem 30
n = int(input())

hundred = (n // 100) % 10
tens = (n // 10) % 10

if hundred + tens == 10 and (hundred > 7 or tens > 7):
    print("Success")
else:
    print("Failure")

# %%
#problem 31
n = int(input())

s = n // 100 + (n // 10) % 10 + n % 10

while s >= 10:
    s = s // 10 + s % 10

print(s)

# %%
#problem 32
a, b = map(int, input().split())

s = a + b

if s < 100:
    print(s)
else:
    print(abs(a - b))

# %%
#problem 33
a, b = map(int, input().split())

if a > b:
    n = a
else:
    n = b

print(n // 10 + n % 10)

# %%
#problem 34
a, b = map(int, input().split())

at = (a // 10) % 10
bt = (b // 10) % 10

if at > bt:
    n = a
else:
    n = b

ones = n % 10
hundred = n // 100

print(abs(ones - hundred))

# %%
#problem 35
a, b = map(int, input().split())

a_sum = a // 100 + a % 10
b_sum = b // 100 + b % 10

if a_sum > b_sum:
    n = a
else:
    n = b

print(n // 100 + (n // 10) % 10 + n % 10)
